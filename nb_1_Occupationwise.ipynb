# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 

plt.style.use("fivethirtyeight")

# %%
df = pd.read_csv(r"C:\Users\Deepti Anand\Desktop\GITHUB\python\project2\employment\occupationwise.csv" , encoding = 'unicode_escape')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Primary_Occupation  32 non-null     object
#  1   Registration_Count  32 non-null     int64
#  2   Last_Updated        32 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 900.0+ bytes

# %%
df.head()
# Out:
#             Primary_Occupation  Registration_Count Last_Updated
# 0                  AGRICULTURE           149939978   23-02-2023
# 1                      APPAREL            17892024   23-02-2023
# 2  AUTOMOBILE & TRANSPORTATION             8006221   23-02-2023
# 3            BEAUTY & WELLNESS             1889448   23-02-2023
# 4                         BFSI               40996   23-02-2023

# %%
df.describe()
# Out:
#        Registration_Count
# count        3.200000e+01
# mean         8.938735e+06
# std          2.669126e+07
# min          1.070000e+02
# 25%          2.460662e+05
# 50%          2.010254e+06
# 75%          5.039352e+06
# max          1.499400e+08

# %%
pd.isnull(df).sum()
# Out:
# Primary_Occupation    0
# Registration_Count    0
# Last_Updated          0
# dtype: int64

# %%
df.drop(["Last_Updated"], axis = 1 , inplace = True)

# %%
df
# Out:
#                              Primary_Occupation  Registration_Count
# 0                                   AGRICULTURE           149939978
# 1                                       APPAREL            17892024
# 2                   AUTOMOBILE & TRANSPORTATION             8006221
# 3                             BEAUTY & WELLNESS             1889448
# 4                                          BFSI               40996
# 5                 CAPITAL GOODS & MANUFACTURING             6732308
# 6                                  CONSTRUCTION            25983686
# 7                DOMESTIC AND HOUSEHOLD WORKERS            27922613
# 8                                     EDUCATION             4858604
# 9                              ELECTRONICS & HW             4732986
# 10                                FOOD INDUSTRY              950338
# 11                              GEM & JEWELLERY              647147
# 12                             GLASS & CERAMICS               58532
# ...

# %%
df.drop([19,22] , axis = 0 , inplace =True)

# %%
sns.set (rc = {'figure.figsize':(20,15)})
sns.barplot( x = "Registration_Count" , y = "Primary_Occupation" , data =df)
# Out:
# <Axes: xlabel='Registration_Count', ylabel='Primary_Occupation'>

# %% [markdown]
# ### It is evident that TOP 3 occupations with highest unorganized workforce is in : Agriculture , Domestic and Household Work , Construction ,respectively .
